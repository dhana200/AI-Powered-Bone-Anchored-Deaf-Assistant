# %% [markdown]
# # **AUDIO CLASSIFICATION AND OPTIMIZATION USING**
# # **GENERATIVE ADVERSARIAL NETWORK**

# %% [markdown]
# ### **CLASSIFICATION OF DATA ACCORDING TO THE SURROUNDINGS**

# %% [markdown]
# ***GENERATING NOISELESS DATA IN CASE OF DISTURBED ENVIRONMENT***

# %%
#NOISY ENVIRONMENT
# Out:
# Frames: 74
# noisy data
# (27456,)
#   4%|▎         | 70/2000 [00:00<00:03, 629.70it/s, loss=0.0659, spectral_convergence=-.948]
# (7, 192, 24, 1)
# Generating...
# Assembling and Converting...
# ...
# 100%|██████████| 2000/2000 [00:03<00:00, 635.26it/s, loss=0.00222, spectral_convergence=-11.2]
# Saving...
# INPUT
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# GENERATED
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ***NOISELESS DATA AND HENCE NO MUCH OPTIMISATION IS NEEDED***

# %%
#NOISELESS DATA
# Out:
# Frames: 74
# noiseless data
# Needs no much optimisation
# (27456,)
#   4%|▍         | 90/2000 [00:00<00:02, 641.27it/s, loss=0.0278, spectral_convergence=-2.4]
# (7, 192, 24, 1)
# 100%|██████████| 2000/2000 [00:03<00:00, 625.98it/s, loss=0.000369, spectral_convergence=-43.1]
# INPUT
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **EFFICIENCY OF THE GAN MODEL**

# %% [markdown]
# # **GENERATED AUDIO SAMPLE**

# %% [markdown]
# ## 5dB SNR

# %%
#GENERATED SAMPLE
# Out:
# (217280,)
#   2%|▏         | 30/2000 [00:00<00:04, 425.67it/s, loss=0.0114, spectral_convergence=-.832]
# (48, 192, 24, 1)
# Generating...
# Assembling and Converting...
# ...
# 100%|██████████| 2000/2000 [00:03<00:00, 619.19it/s, loss=0.00211, spectral_convergence=-15.1]
# Saving...
# Saved WAV!
# INPUT
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# GENERATED
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 7dB SNR

# %%
#7dB SNR
# Out:
# (27456,)
#   4%|▎         | 70/2000 [00:00<00:03, 628.12it/s, loss=0.0341, spectral_convergence=-2.73]
# (7, 192, 24, 1)
# Generating...
# Assembling and Converting...
# ...
# 100%|██████████| 2000/2000 [00:03<00:00, 637.48it/s, loss=0.00237, spectral_convergence=-12.6]
# Saving...
# Saved WAV!
# INPUT
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# GENERATED
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 8dB SNR

# %%
#8dB SNR
# Out:
# (27456,)
#   4%|▎         | 70/2000 [00:00<00:03, 627.88it/s, loss=0.0836, spectral_convergence=-1.49]
# (7, 192, 24, 1)
# Generating...
# Assembling and Converting...
# ...
# 100%|██████████| 2000/2000 [00:03<00:00, 637.18it/s, loss=0.00138, spectral_convergence=-10.7]
# Saving...
# Saved WAV!
# INPUT
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# GENERATED
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 10dB SNR

# %%
#10dB SNR
# Out:
# (27456,)
#   4%|▍         | 80/2000 [00:00<00:02, 655.27it/s, loss=0.0255, spectral_convergence=-3.57]
# (7, 192, 24, 1)
# Generating...
# Assembling and Converting...
# ...
# 100%|██████████| 2000/2000 [00:03<00:00, 633.83it/s, loss=0.00365, spectral_convergence=-12.6]
# Saving...
# Saved WAV!
# INPUT
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# GENERATED
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 15dB SNR

# %%
#15dB SNR
# Out:
# (27456,)
#   4%|▎         | 70/2000 [00:00<00:03, 639.04it/s, loss=0.0146, spectral_convergence=-2.38]
# (7, 192, 24, 1)
# Generating...
# Assembling and Converting...
# ...
# 100%|██████████| 2000/2000 [00:03<00:00, 643.97it/s, loss=0.00364, spectral_convergence=-12.1]
# Saving...
# Saved WAV!
# INPUT
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# GENERATED
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 0dB SNR (Threshold: Breakdown Case)

# %%
#0dB
# Out:
# (27456,)
#   4%|▎         | 70/2000 [00:00<00:03, 639.25it/s, loss=0.081, spectral_convergence=-1.35]
# (7, 192, 24, 1)
# Generating...
# Assembling and Converting...
# ...
# 100%|██████████| 2000/2000 [00:03<00:00, 606.59it/s, loss=0.000633, spectral_convergence=-9.03]
# Saving...
# Saved WAV!
# INPUT
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# GENERATED
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
